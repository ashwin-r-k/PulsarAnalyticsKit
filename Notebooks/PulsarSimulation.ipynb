# %%
from blimpy import Waterfall
# Out:
# /opt/userapps/conda-envs/psrSim/lib/python3.13/site-packages/blimpy/__init__.py:21: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
file = "/home/ashwin/Downloads/blc20_guppi_57991_49318_DIAG_PSR_J0332+5434_0008.gpuspec.0002.fil"
fil = Waterfall(file)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
fil.plot_waterfall()

# %%
plt.figure(figsize=(10,6))
fil.plot_waterfall(f_start=6525, f_stop=6560)

# %%
plt.figure(figsize=(10,6))
fil.plot_spectrum(t=55) #Leaving arguments blank will cause it to show integration 0 by default
# Out:
# extracting integration 55...

# %%
fil.info()
# Out:
# --- File Info ---
#      rawdatafile : guppi_57991_49318_DIAG_PSR_J0332+5434_0008.0000.raw
#      source_name :              DIAG_PSR_J0332+5434
#       machine_id :                               20
#     telescope_id :                                6
#          src_raj :                      3:32:59.184
#          src_dej :                      54:34:43.68
#         az_start :                              0.0
#         za_start :                              0.0
#        data_type :                                1
#             fch1 :                6688.96484375 MHz
#             foff :         -0.00286102294921875 MHz
#           nchans :                            65536
#           nbeams :                                1
#            ibeam :                                1
#            nbits :                               32
#    tstart (ISOT) :          2017-08-26T13:41:58.000
#     tstart (MJD) :               57991.570810185185
# ...

# %%
freqs = fil.freqs
print (freqs)
print (len(freqs))
# Out:
# [6688.96484375 6688.96198273 6688.9591217  ... 6501.47342682 6501.4705658
#  6501.46770477]
# 65536

# %%
# save this data to a text file
import numpy as np

np.savetxt("rd.txt", freqs, fmt='%.8f')
